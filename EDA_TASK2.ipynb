# %% [markdown]
# <a href="https://colab.research.google.com/github/cheth-dev/Mainflow_internship/blob/main/EDA_TASK2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("/content/Global_Superstore(CSV).csv")
# 1. Data Cleaning
# Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True)

df.dropna(inplace=True)  # Drop remaining NaNs if necessary

# Remove duplicates
df.drop_duplicates(inplace=True)

# 2. Statistical Analysis
print("Summary Statistics:")
print(df.describe())

# Correlation matrix
correlation_matrix = df.corr(numeric_only=True)
print("\nCorrelation Matrix:")
print(correlation_matrix)

# 3. Data Visualization
sns.set(style="whitegrid")

# Histogram
plt.figure(figsize=(10, 5))
sns.histplot(df['Sales'], bins=50, kde=True)
plt.title("Sales Distribution")
plt.show()

# Boxplot for detecting outliers
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['Profit'])
plt.title("Profit Outliers")
plt.show()

# Heatmap for correlation
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# Summary Statistics:
#              Row ID   Postal Code        Sales    Quantity     Discount  \
# count   1000.000000   1000.000000  1000.000000  1000.00000  1000.000000
# mean   25079.328000  53966.170103  1710.971470     5.55800     0.092840
# std    12897.726632  14827.491933  1259.239238     2.71846     0.148666
# min       58.000000   2920.000000     1.910000     1.00000     0.000000
# 25%    15118.750000  53966.170103   826.907500     4.00000     0.000000
# 50%    25084.500000  53966.170103  1585.115000     5.00000     0.000000
# 75%    34524.000000  53966.170103  2477.812500     7.00000     0.150000
# max    51284.000000  98198.000000  9892.740000    14.00000     0.800000
#
#             Profit  Shipping Cost
# count  1000.000000    1000.000000
# mean    288.920440     272.384897
# std     574.504782     176.160716
# min   -3059.820000       1.070000
# 25%      10.037500     209.827500
# 50%     190.685000     258.897500
# 75%     518.872500     351.070250
# ...
